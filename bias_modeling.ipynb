# %% [markdown]
# # Modeling Bias

# %% [markdown]
# ### Load data

# %%
import pandas as pd
import geopandas as gpd
import zipfile
from data_functions import load_data

# %%
# load in cleaned data
stops_path = r"./data/stops_clean.csv.zip"
stops_df = load_data(stops_path)
# Out:
# Unzipped

# %% [markdown]
# ### Create Training, Testing, Validation Sets

# %% [markdown]
# #### Split Data by policy date
