# %% [markdown]
# # Modeling: San Francisco Traffic Stops

# %%
# %pip install -r "requirements.txt"

# import necessary libraries and functions
from bias_analysis_functions import *
from bias_modeling_functions import *
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
import optuna

# %% [markdown]
# Initialize Set-Up values for model

# %%
### Hardcoded Values

CONFIG = {
    "policy_date": "2014-03-01",
    # categorical predictors
    "categorical_cols": [
        'month', 'day_of_week', 'light_condition',
        'subject_race', 'subject_sex', 'district', 'epc_class'
    ],
    # feature of interest
    "outcome_col": "outcome",
    "epc_col": "epc_class",
    "n_trials": 50,
    # seed
    "random_state": 42
}

# %%
# load data
stop_path = r"../data/clean_data/stops_clean.csv.zip"
stops_df = load_data(stop_path)
# Out:
# stops_clean.csv.zip file unzipped.
# stops_clean.csv.zip converted to dataframe.

# %%
run_model_pipeline(stops_df, CONFIG)
